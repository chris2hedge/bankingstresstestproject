# %%
import pandas as pd

# %%
df1 = pd.read_csv("Stress Test Data Table 1.A - Sheet1.csv")
df2 = pd.read_csv("Stress Test Data Table 3.A - Sheet1.csv")
df3 = pd.read_csv("FRB_H8.csv")
print(df1.head())
print(df2.head())
print(df3.head())
# Out:
#       Date  Real GDP Growth   Nominal GDP Growth
# 0  Q1 2000               1.5                 4.2  \
# 1  Q2 2000               7.5                10.2
# 2  Q3 2000               0.4                 2.8
# 3  Q4 2000               2.4                 4.6
# 4  Q1 2001              -1.3                 1.3
#
#    Real Disposable Income Growth  Nominal Dispoable Income Growth
# 0                            7.2                             10.7  \
# 1                            4.9                              6.9
# 2                            5.3                              8.0
# 3                            2.5                              4.9
# 4                            3.3                              6.4
#
#    Unemployment rate  CPI Inflation rate  3-month Treasury Rate
# 0                4.0                 4.0                    5.5  \
# 1                3.9                 3.2                    5.7
# 2                4.0                 3.7                    6.0
# ...

# %%
df1.columns
# Out:
# Index(['Date', 'Real GDP Growth ', 'Nominal GDP Growth',
#        'Real Disposable Income Growth', 'Nominal Dispoable Income Growth',
#        'Unemployment rate', 'CPI Inflation rate', '3-month Treasury Rate',
#        '5-year Treasury Rate', '10-year Treasury Rate', 'BBB corporate yield',
#        'Mortgage Rate', 'Prime Rate', 'Dow Jones Stock Market Index',
#        'Level House Price Index', 'Commercial Real Estate Price Index',
#        'Market Volatility Index'],
#       dtype='object')

# %%
df1["Nominal GDP Growth"]
# Out:
# 0      4.2
# 1     10.2
# 2      2.8
# 3      4.6
# 4      1.3
#       ...
# 83     6.6
# 84    10.9
# 85    13.4
# 86     8.4
# 87    11.5
# Name: Nominal GDP Growth, Length: 88, dtype: float64

# %%
df2.columns
# Out:
# Index(['Date', 'Real GDP Growth ', 'Nominal GDP Growth',
#        'Real Disposable Income Growth', 'Nominal Dispoable Income Growth',
#        'Unemployment rate', 'CPI Inflation rate', '3-month Treasury Rate',
#        '5-year Treasury Rate', '10-year Treasury Rate', 'BBB corporate yield',
#        'Mortgage Rate', 'Prime Rate', 'Dow Jones Stock Market Index',
#        'Level House Price Index', 'Commercial Real Estate Price Index',
#        'Market Volatility Index'],
#       dtype='object')

# %%
df2["Prime Rate"]
# Out:
# 0     3.1
# 1     3.1
# 2     3.1
# 3     3.1
# 4     3.1
# 5     3.1
# 6     3.1
# 7     3.1
# 8     3.1
# 9     3.1
# 10    3.1
# 11    3.1
# 12    3.1
# Name: Prime Rate, dtype: float64

# %%
df3.columns
# Out:
# Index(['Time Period',
#        'Bank credit, domestically chartered commercial banks, seasonally adjusted',
#        'Securities in bank credit, domestically chartered commercial banks, seasonally adjusted',
#        'Treasury and agency securities, domestically chartered commercial banks, seasonally adjusted',
#        'Treasury and agency securities: Mortgage-backed securities (MBS), domestically chartered commercial banks, seasonally adjusted',
#        'Treasury and agency securities: Non-MBS, domestically chartered commercial banks, seasonally adjusted',
#        'Other securities, domestically chartered commercial banks, seasonally adjusted',
#        'Other securities: Mortgage-backed securities, domestically chartered commercial banks, seasonally adjusted',
#        'Other securities: Non-MBS, domestically chartered commercial banks, seasonally adjusted',
#        'Loans and leases in bank credit, domestically chartered commercial banks, seasonally adjusted',
# ...

# %%
df3["Time Period"]
# Out:
# 0      1973-01
# 1      1973-02
# 2      1973-03
# 3      1973-04
# 4      1973-05
#         ...
# 598    2022-11
# 599    2022-12
# 600    2023-01
# 601    2023-02
# 602    2023-03
# Name: Time Period, Length: 603, dtype: object
